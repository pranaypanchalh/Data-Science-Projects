# %%
import pandas as pd

csvFile = pd.read_csv("customers-2000000.csv")
df = pd.DataFrame(csvFile)
df.info()
print("Hello World")
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2000000 entries, 0 to 1999999
# Data columns (total 12 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Index              int64
#  1   Customer Id        str
#  2   First Name         str
#  3   Last Name          str
#  4   Company            str
#  5   City               str
#  6   Country            str
#  7   Phone 1            str
#  8   Phone 2            str
#  9   Email              str
#  10  Subscription Date  str
#  11  Website            str
# dtypes: int64(1), str(11)
# memory usage: 183.1 MB
