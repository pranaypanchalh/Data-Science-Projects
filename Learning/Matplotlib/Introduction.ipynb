# %%
import pandas as pd
import matplotlib.pyplot as plt

csv = pd.read_csv("../../Formula1 Datasets/Formula1_2026Season_SprintResults.csv")
myPlt = plt 
myPlt.plot(csv["Track"],csv["Points"])
csv
# Out:
#            Track Position  No           Driver                Team  \
# 0          China        1  63   George Russell            Mercedes
# 1          China        2  16  Charles Leclerc             Ferrari
# 2          China        3  44   Lewis Hamilton             Ferrari
# 3          China        4   1     Lando Norris    McLaren Mercedes
# 4          China        5  12   Kimi Antonelli            Mercedes
# ..           ...      ...  ..              ...                 ...
# 105  Netherlands       18  14  Fernando Alonso  Aston Martin Honda
# 106  Netherlands       19  77  Valtteri Bottas    Cadillac Ferrari
# 107  Netherlands       20  55     Carlos Sainz   Williams Mercedes
# 108  Netherlands       21  11     Sergio Perez    Cadillac Ferrari
# 109  Netherlands       NC  27  Nico Hulkenberg                Audi
#
#      Starting Grid  Laps Time/Retired  Points
# 0                1    19    33:38.998       8
# 1                6    19       +0.674       7
# ...
