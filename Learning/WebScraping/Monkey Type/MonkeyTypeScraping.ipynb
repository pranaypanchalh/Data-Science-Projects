# %%
#DOESN'T WORK

from bs4 import BeautifulSoup as bs
import requests as rq
import pandas as pd
import numpy as np

#Generate offline file

url = "https://monkeytype.com/leaderboards?type=allTime&mode=time&mode2=60&language=english&page=1"

rp = rq.get(url)

print(rp.text)

def saveOfflineFile():
    with open("MonkeyTypeLeaderboard.html", "w") as f:
        f.write(rp.text)

saveOfflineFile()
# Out:
# <!doctype html><html lang="en"><head><link rel="preload" href="/css/monkeytype.DbILj5t4.css" type="text/css" as="style" crossorigin><link rel="preload" href="/css/standalone.BowSyp6T.css" type="text/css" as="style" crossorigin><link rel="preload" href="/webfonts/fa-brands-400-BJEvs-YL.woff2" type="font/woff2" as="font" crossorigin><link rel="preload" href="/webfonts/fa-regular-400-CPEIu2bx.woff2" type="font/woff2" as="font" crossorigin><link rel="preload" href="/webfonts/fa-solid-900-COjqfJMd.woff2" type="font/woff2" as="font" crossorigin><link rel="preconnect" href="https://api.monkeytype.com"><link rel="preconnect" href="https://identitytoolkit.googleapis.com"><link rel="preconnect" href="https://www.google.com"><link rel="preconnect" href="https://www.gstatic.com"><link rel="preload" href="/webfonts/RobotoMono-Regular.woff2" type="font/woff2" as="font" crossorigin><link rel="preload" href="/webfonts/LexendDeca-Regular.woff2" type="font/woff2" as="font" crossorigin><script>document
# ...
