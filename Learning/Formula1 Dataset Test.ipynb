# %%
import pandas as pd

df = pd.read_csv("../Formula1 Datasets/Formula1_2026Season_SprintResults.csv")
df["Laps"].sort_values()
# Out:
# <bound method Series.sort_values of 0      19
# 1      19
# 2      19
# 3      19
# 4      19
#        ..
# 105    24
# 106    23
# 107    23
# 108    21
# 109     7
# Name: Laps, Length: 110, dtype: int64>
