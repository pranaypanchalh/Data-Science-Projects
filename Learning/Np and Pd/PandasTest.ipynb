# %%
import pandas as pd

csvFile = pd.read_csv("https://codewithharry.nyc3.cdn.digitaloceanspaces.com/dashboard/lesson/creating-dataframes-1745077860781/1745500125912-data.csv")
df = pd.DataFrame(csvFile)
df.info()
print("Hello World")
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Actor                 12 non-null     str
#  1   Film                  12 non-null     str
#  2   Year                  12 non-null     int64
#  3   Genre                 12 non-null     str
#  4   BoxOffice(INR Crore)  12 non-null     int64
#  5   IMDb                  12 non-null     float64
# dtypes: float64(1), int64(2), str(3)
# memory usage: 708.0 bytes
# Hello World
