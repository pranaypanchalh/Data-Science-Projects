# %%
import pandas as pd

# Sample DataFrame
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Math': [85, 78, 92],
    'Science': [90, 82, 89],
    'English': [88, 85, 94]
}

df = pd.DataFrame(data)

df2 = df.melt(id_vars="Name", value_vars=["Math", "Science", "English"], var_name="Subject", value_name="Score")
df3 = df2.pivot_table(index="Name", columns="Subject", values="Score", aggfunc="mean")
df3
# Out:
# Subject  English  Math  Science
# Name
# Alice       88.0  85.0     90.0
# Bob         85.0  78.0     82.0
# Charlie     94.0  92.0     89.0
